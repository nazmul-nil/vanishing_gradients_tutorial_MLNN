# %% [markdown]
# # Vanishing and Exploding Gradients in Deep Learning
#
# # Nazmul Hossain | 23015862

# %%
# importing necessary libraries
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import BatchNormalization

# %%
# Create a deep neural network with Sigmoid activation
model = Sequential([
    Dense(100, activation='sigmoid', input_shape=(100,)),
    *[Dense(100, activation='sigmoid') for _ in range(9)],
    Dense(1)
])

# Compile the model
model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.01), loss='mse')

# Generate random data
x = np.random.rand(1000, 100).astype(np.float32)
y = np.random.rand(1000, 1).astype(np.float32)

# Train the model
model.fit(x, y, epochs=5, batch_size=32)
# Out:
# C:\Users\Nazm\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0967
# Epoch 2/5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0876
# Epoch 3/5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0862
# Epoch 4/5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0877
# Epoch 5/5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0836

# %%
# Define a custom initializer with large weights
large_weights_initializer = tf.keras.initializers.RandomUniform(minval=0.9, maxval=1.1)

# Create a deep neural network with poor weight initialization
model = Sequential([
    Dense(100, kernel_initializer=large_weights_initializer, activation='relu', input_shape=(100,)),
    *[Dense(100, kernel_initializer=large_weights_initializer, activation='relu') for _ in range(9)],
    Dense(1)
])

# Compile and train (same as above)
model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.01), loss='mse')
model.fit(x, y, epochs=5, batch_size=32)
# Out:
# Epoch 1/5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: nan
# Epoch 2/5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: nan
# Epoch 3/5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: nan
# Epoch 4/5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: nan
# Epoch 5/5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: nan

# %%
# Replace Sigmoid activation with ReLU
model = Sequential([
    Dense(100, activation='relu', input_shape=(100,)),
    *[Dense(100, activation='relu') for _ in range(9)],
    Dense(1)
])

# Compile and train (same as above)
model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.01), loss='mse')
model.fit(x, y, epochs=5, batch_size=32)
# Out:
# Epoch 1/5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2275
# Epoch 2/5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0886
# Epoch 3/5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0843
# Epoch 4/5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0876
# Epoch 5/5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0822

# %%
# Use Xavier Initialization (Glorot Uniform in TensorFlow)
model = Sequential([
    Dense(100, kernel_initializer='glorot_uniform', activation='relu', input_shape=(100,)),
    *[Dense(100, kernel_initializer='glorot_uniform', activation='relu') for _ in range(9)],
    Dense(1)
])

# Compile and train (same as above)
model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.01), loss='mse')
model.fit(x, y, epochs=5, batch_size=32)
# Out:
# Epoch 1/5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2193
# Epoch 2/5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0899
# Epoch 3/5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0872
# Epoch 4/5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0852
# Epoch 5/5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0834

# %%
# Add Batch Normalization to stabilize gradients
model = Sequential([
    Dense(100, activation='relu', input_shape=(100,)),
    BatchNormalization(),
    *[Sequential([Dense(100, activation='relu'), BatchNormalization()]) for _ in range(9)],
    Dense(1)
])

# Compile and train
model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.01), loss='mse')
model.fit(x, y, epochs=5, batch_size=32)
# Out:
# Epoch 1/5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.0454
# Epoch 2/5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3851
# Epoch 3/5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2581
# Epoch 4/5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2074
# Epoch 5/5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1556

# %%
# Use SGD with gradient clipping
optimizer = tf.keras.optimizers.SGD(learning_rate=0.01, clipnorm=1.0)

# Compile the model with the custom optimizer
model.compile(optimizer=optimizer, loss='mse')

# Train the model
model.fit(x, y, epochs=5, batch_size=32)
# Out:
# Epoch 1/5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.1600
# Epoch 2/5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1357
# Epoch 3/5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1155
# Epoch 4/5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1158
# Epoch 5/5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1006

# %%
# Generate random data
x = np.random.rand(1000, 100).astype(np.float32)
y = np.random.rand(1000, 1).astype(np.float32)

# Check for missing or invalid data
x = np.nan_to_num(x)
y = np.nan_to_num(y)

# Create a deep neural network
model = Sequential([
    Dense(100, activation='relu', input_shape=(100,)),
    *[Dense(100, activation='relu') for _ in range(9)],
    Dense(1)
])

# Compile the model
model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.01), loss='mse')

# Train the model
model.fit(x, y, epochs=5, batch_size=32)
# Out:
# Epoch 1/5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1930
# Epoch 2/5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0903
# Epoch 3/5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0857
# Epoch 4/5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0865
# Epoch 5/5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0829

# %%
class GradientLogger(tf.keras.callbacks.Callback):
    def __init__(self, x_data, y_data):
        super().__init__()
        self.x_data = x_data
        self.y_data = y_data

    def on_train_batch_end(self, batch, logs=None):
        # Use GradientTape to compute gradients
        with tf.GradientTape() as tape:
            predictions = self.model(self.x_data, training=True)
            loss = self.model.compiled_loss(self.y_data, predictions)

        # Compute gradients
        gradients = tape.gradient(loss, self.model.trainable_weights)
        
        # Log gradient norms
        gradient_norms = [tf.norm(g).numpy() for g in gradients if g is not None]
        print(f"Batch {batch + 1}, Gradient Norms: {gradient_norms}")

# %%
# Generate synthetic data
x = np.random.rand(1000, 100).astype(np.float32)
y = np.random.rand(1000, 1).astype(np.float32)

# Define the deep neural network
model = Sequential([
    Dense(100, activation='relu', input_shape=(100,)),
    *[Dense(100, activation='relu') for _ in range(9)],
    Dense(1)
])

# Compile the model
model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.01), loss
# 27/32 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.2499Batch 28, Gradient Norms: [0.018447567, 0.0036534758, 0.017985158, 0.0054851235, 0.019626562, 0.00863866, 0.019471094, 0.01369164, 0.019913508, 0.01950749, 0.02493933, 0.036330078, 0.024412002, 0.048492942, 0.027641108, 0.09050394, 0.031027662, 0.14689738, 0.04691975, 0.2757538, 0.079550646, 0.33667958]
# Batch 29, Gradient Norms: [0.018080002, 0.003579544, 0.017601192, 0.005363935, 0.019089814, 0.008396691, 0.018874103, 0.013260321, 0.019288013, 0.018886851, 0.024170948, 0.035169456, 0.02367575, 0.046988487, 0.02679701, 0.087376475, 0.030169452, 0.14181721, 0.04594416, 0.26643476, 0.07804583, 0.32491046]
# 29/32 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.2457Batch 30, Gradient Norms: [0.017018834, 0.0033647607, 0.016567506, 0.0050422656, 0.017981691, 0.007902304, 0.017857814, 0.012536677, 0.018216465, 0.01781494, 0.022676462, 0.032923013, 0.022258671, 0.04399592, 0.025119571, 0.08129697, 0.02837096, 0.13158889, 0.043733813, 0.24722922, 0.07467468, 0.3011014]
# Batch 31, Gradient Norms: [0.016118526, 0.0031859863, 0.015518417, 0.0047192457, 0.016746623, 0.007351859, 0.016723305, 0.011721219, 0.016974827, 0.016576324, 0.021128379, 0.030615624, 0.0208629, 0.041124474, 0.0234858, 0.07556617, 0.026682666, 0.12230047, 0.041578814, 0.22998965, 0.07128745, 0.27955136]
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.2417Batch 32, Gradient Norms: [0.01581495, 0.003125525, 0.015149885, 0.004598884, 0.016151905, 0.0070797303, 0.015903853, 0.011128395, 0.016006382, 0.015632737, 0.019900361, 0.028830547, 0.019634843, 0.038675334, 0.022145757, 0.071082965, 0.025269656, 0.115040444, 0.039569054, 0.21504276, 0.06819693, 0.26137143]
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.2382

# %%
# Create a figure for the plots
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# Data for vanishing gradients
layers = np.arange(1, 11)  
vanishing_gradients = np.exp(-layers)

# Data for exploding gradients
exploding_gradients = np.exp(layers)

# Vanishing Gradients Plot
axes[0].plot(layers, vanishing_gradients, marker='o', label='Gradient Norm')
axes[0].set_title("Vanishing Gradients")
axes[0].set_xlabel("Layer (from Output to Input)")
axes[0].set_ylabel("Gradient Norm")
axes[0].invert_xaxis()
axes[0].grid(True)
axes[0].legend()

# Exploding Gradients Plot
axes[1].plot(layers, exploding_gradients, marker='o', color='r', label='Gradient Norm')
axes[1].set_title("Exploding Gradients")
axes[1].set_xlabel("Layer (from Output to Input)")
axes[1].set_ylabel("Gradient Norm")
axes[1].invert_xaxis()
axes[1].grid(True)
axes[1].legend()

# Adjust layout and display
plt.tight_layout()
plt.show()

# %%
# Simulated training loss data
epochs = np.arange(1, 21)
loss_no_fixes = np.linspace(1.5, 0.8, len(epochs)) + 0.1 * np.random.rand(len(epochs))
loss_relu = np.linspace(1.5, 0.5, len(epochs))
loss_batch_norm = np.linspace(1.5, 0.4, len(epochs))

# Create the plot
plt.figure(figsize=(8, 6))
plt.plot(epochs, loss_no_fixes, label="No Fixes", color="#CC79A7", marker='o')
plt.plot(epochs, loss_relu, label="With ReLU", color="#0072B2", marker='s')
plt.plot(epochs, loss_batch_norm, label="With Batch Norm", color="#009E73", marker='d')

# Add labels and title
plt.title("Loss Curves for Different Techniques", fontsize=14)
plt.xlabel("Epoch", fontsize=12)
plt.ylabel("Loss", fontsize=12)
plt.legend()
plt.grid(True)
plt.show()

# %%
# Simulate loss values
epochs = np.arange(1, 21)
loss_vanishing = np.linspace(1, 0.5, len(epochs)) + 0.1 * np.random.rand(len(epochs))
loss_solved = np.linspace(1, 0.1, len(epochs))

# Create plot
plt.figure(figsize=(8, 6))
plt.plot(epochs, loss_vanishing, label="Without Fixes", color="#CC79A7", marker='s')
plt.plot(epochs, loss_solved, label="With Fixes", color="#009E73", marker='o')

# Add labels and title
plt.title("Loss Reduction Over Epochs", fontsize=14)
plt.xlabel("Epoch", fontsize=12)
plt.ylabel("Loss", fontsize=12)
plt.legend()
plt.grid(True)
plt.show()
